# %% [markdown]
# ---
# ---
#
#
# In this module, we're are going to explore how powerful EDA can be by using it to answer am important question faced by many movie production companies.
#
#
# ---
#
#
# Every year, the elite production companies, powerhouse actors and actresses gather for the coveted night of Academy Awards! Of course some go home with the most prestigious awards, others get a mention recoginition, yet still some are never recognized.
#
#
# ---
#
# Can you use a companies internal production data to help it produce an award winning movie?
#
# ---
# ---

# %%
# Load packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Read in data
IMDB_Data = pd.read_csv("https://raw.githubusercontent.com/Mcpaeis/code-s/master/IMDB-Movie-Data.csv", sep=",", header=0)

IMDB_Data.head()
# Out:
#    Rank                    Title  ... Revenue (Millions) Metascore
# 0     1  Guardians of the Galaxy  ...             333.13      76.0
# 1     2               Prometheus  ...             126.46      65.0
# 2     3                    Split  ...             138.12      62.0
# 3     4                     Sing  ...             270.32      59.0
# 4     5            Suicide Squad  ...             325.02      40.0
#
# [5 rows x 12 columns]

# %%
### Add a new column to the dataframe
IMDB_Data['Won Award'] = IMDB_Data.Metascore >= 72
IMDB_Data.head()
# Out:
#    Rank                    Title  ... Metascore Won Award
# 0     1  Guardians of the Galaxy  ...      76.0      True
# 1     2               Prometheus  ...      65.0     False
# 2     3                    Split  ...      62.0     False
# 3     4                     Sing  ...      59.0     False
# 4     5            Suicide Squad  ...      40.0     False
#
# [5 rows x 13 columns]

# %% [markdown]
# ---
# ---
#
# ## Question (1)
#
# ---
# ---
#
#
# (a)  Create a three (3) new features call "Actor 1", "Actor 2", and "Actor 3" by splitting the "Actors" column strings and taking the first three items to form these columns values. Refer to the EDA video on how to do this.
#
#
# (b)   Create a new feature call "Genre 1" by splitting the "Genre" column strings and taking the first item to form this feature.

# %% [markdown]
# ---
# ---
#
# ## Question (2)
#
# ---
# ---
#
# (a) Summarize the missing count of each feature in the data set.
#
# (b) Remove the missing observations from the dataset and show that the've ben removed.

# %% [markdown]
# ---
# ---
#
# ## Question (3)
#
# ---
# ---
#
# (a) Identify the most common Genre in this dataset based on the "Genre 1" feature.
#
# (b) Identify the top five (5) high grossing genres. That is genres that have the highest revenues.
#
# (c) Identify the most common actors in each of the three actor features (Actor 1, Actor 2, Actor3)
#
# (d) Based on only the "Actor 1" feature, identify the five highest grossing actors based on the revenue variable.
#
# (c) Based on only the "Director" feature, identify the five highest grossing directors based on the revenue variable.

# %% [markdown]
# ---
# ---
#
# ## Question (4)
#
# ---
# ---
#
# (a) For the top five(5) common actors/actresses, determine the number of awards won.
#
# (b) Determine the number of awards won for the top 5 directors.
#
# (c) For the top five common genres, determine the number of awards won by each.

# %% [markdown]
# ---
# ---
#
# ## Question (5)
#
# ---
# ---
#
# (a) List the top 5 combination of Director, Actors, and Genre with the highest gross revenue.
#
# (b) List the top 5 combination of Director, Actors, and Genre with the highest number of awards won.
